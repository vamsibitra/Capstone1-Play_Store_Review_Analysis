# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsibitra/Capstone1-Play_Store_Review_Analysis/blob/main/Final_Capstone1_EDA_Submission_Template_Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  Play Store App Review Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** Vamsi Bitra
# ##### **Team Member 2 -** Anjali Bathula

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# Developers and businesses continually seek ways to not only create innovative apps but also ensure their success in the Google Play Store, one of the world's largest app distribution platforms. To thrive in this environment, it is imperative to harness the power of data analytics. Over 1.5 billion Android smartphones were shipped last year(2022) this is the rough estimation that shows the number of users of play store. The most popular downloaded apps all over the world are TikTok, Instagram, Facebook, WhatsApp, Telegram till now. This shows that these apps got the better review by so many users. Some apps which got very few downloads, this tells us these apps are negatively reviewed.
#
# The Play Store Apps Review Analysis project aims to unlock the vast potential hidden within app reviews and metadata to provide actionable insights for developers, thereby driving app-making businesses towards success.
#
# #**Project Data**
#
# The core of the Play Store Apps Review Analysis project revolves around two datasets:
#
#
# **Play Store Apps Dataset**: This dataset contains comprehensive information about various Android applications available on the Play Store. Each entry provides valuable details such as the app's category, user ratings, size, and several other attributes.
#
# **Customer Reviews Dataset:** Complementing the primary dataset is a repository of customer reviews for these Android apps. These reviews are a valuable source of user-generated content, offering insights into user sentiments, opinions, and feedback.
#
# The journey of this project begins with an extensive data exploration phase. Here, the team conducts comprehensive data cleaning and preprocessing, ensuring that the datasets are in optimal shape for subsequent analysis. This crucial step lays the foundation for all subsequent insights and findings.
#
# Sentiment analysis is a pivotal aspect of the project, leveraging advanced natural language processing techniques to delve into the Customer Reviews Dataset. The objective is to extract sentiment insights from user-generated content, shedding light on how users perceive and engage with different apps. This analysis goes beyond quantitative metrics, providing a nuanced understanding of user sentiments, opinions, and feedback.
#
# Identifying the key factors responsible for app engagement and success is a fundamental goal of the project. This involves a multifaceted approach, including the identification of trends among highly-rated apps, an examination of the impact of app size on download rates, and an investigation into whether specific app categories possess a more substantial user appeal. By identifying these factors, developers and businesses can make data-informed decisions about their app development, marketing strategies, and user experience enhancements.
#
# #**Benefits**
#
# The Play Store Apps Review Analysis project offers several benefits:
#
# **Informed Decision-Making:** Developers and businesses can make informed decisions based on user data, enhancing their app's design, marketing strategies, and user experience.
#
# **Competitive Advantage:** Access to actionable insights can give businesses a competitive edge in a crowded app marketplace, helping them stand out and attract more users.
#
# **Improved User Satisfaction:** Addressing user preferences and pain points can lead to increased user satisfaction, reflected in higher app ratings and more downloads.
#
# **Data-Driven Growth:** Businesses can use data-driven strategies to drive growth, expand their presence in the Android app market, and adapt to changing trends.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/vamsibitra/Capstone1-Play_Store_Review_Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Google Play Store is one of the most used app market in the world. But there are some faults in the apps that are present in the play store. We explore and analyse the data given by both google and it's users and give major responsibilities for the app to get success and some profit.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
#  Effectively managing and leveraging app reviews can contribute to the overall success of an app in the marketplace.
#
# The Business Objectives of Google Play Store App are:
#
#
# * **User Feedback and Improvement:** Here we are going to collect the play store reviews given to each app. The coders of these app are going to look into the reviews and going to develop much better and solve the issues, bugs or user experience problems in their app. There are going to develop their app functionality continuously.
# * **App Rating and Visibility:** Positive reviews can improve an app's overall rating on the Play Store, making it more attractive to potential users. A higher rating can increase an app's visibility in search results and category rankings, leading to more downloads and installs.
# * **User Engagement:** Engaging with users through the review section can help build a sense of community around the app. Responding to reviews, both positive and negative, demonstrates that the developer values user input and is actively working to address concerns. This can enhance user loyalty and encourage more reviews.
# * **Competitive Analysis:** Analyzing competitor's app reviews can provide insights into what users like and dislike about competing apps. This information can be used to refine your app's features and user experience to gain a competitive edge.
# * **Feature Prioritization:** Reviews often contain feature requests and suggestions from users. Analyzing these requests can help prioritize which new features or improvements to implement, aligning the app's development roadmap with user preferences.
# * **Customer Support and Issue Resolution:** Negative reviews can highlight specific problems that users are facing. Responding to these reviews promptly and resolving issues can prevent users from churning and leaving poor ratings. Effective customer support through the review section can lead to improved user satisfaction and loyalty.
# * **Marketing and Promotion:** Positive reviews and high app ratings can be used as marketing assets. Developers can showcase these reviews in promotional materials, advertisements, and app descriptions to attract potential users and build trust in their app.
# * **User Acquisition:** Encouraging satisfied users to leave reviews can serve as a form of user-generated content that can attract new users. Apps with positive reviews and high ratings are more likely to be considered by potential users looking for new apps to download.
# * **App Monetization:** Some apps monetize through in-app purchases, ads, or subscriptions. Positive reviews and high user satisfaction can lead to increased engagement and monetization opportunities.
# * **Compliance and Quality Assurance:** Monitoring reviews can help developers ensure that their app complies with Play Store policies and quality guidelines. It can also help identify any issues that may arise from software updates or changes in the app's functionality.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
play_store_data = pd.read_csv("/content/drive/MyDrive/capstone 1/Play Store Data.csv")
user_reviews = pd.read_csv("/content/drive/MyDrive/capstone 1/User Reviews.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
ps_data = play_store_data.head()
print(f"The first 5 values of Play Store dataset are below")
ps_data
# Out:
# The first 5 values of Play Store dataset are below
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
ur_data = user_reviews.head()
print(f"The first 5 values of User reviews dataset are below")
ur_data
# Out:
# The first 5 values of User reviews dataset are below
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
ps_shape = play_store_data.shape
print(f"The Playstore dataset consists of {ps_shape[0]} rows and {ps_shape[1]} columns.")
# Out:
# The Playstore dataset consists of 10841 rows and 13 columns.

# %%
ur_shape = user_reviews.shape
print(f"The User reviews dataset consists of {ur_shape[0]} rows and {ur_shape[1]} columns.")
# Out:
# The User reviews dataset consists of 64295 rows and 5 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
ps_info = play_store_data.info()
print(ps_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB
# None

# %%
ur_info = user_reviews.info()
print(ur_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB
# None

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
new_ps_data = play_store_data.copy()
new_ps_data = new_ps_data.drop_duplicates()
new_ps_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
new_ur_data = user_reviews.copy()
new_ur_data = new_ur_data.drop_duplicates()
new_ur_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30679 entries, 0 to 64236
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     30679 non-null  object
#  1   Translated_Review       29692 non-null  object
#  2   Sentiment               29697 non-null  object
#  3   Sentiment_Polarity      29697 non-null  float64
#  4   Sentiment_Subjectivity  29697 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(f"The missing values or null values count in Play store data is {new_ps_data.isnull().sum().sum()}")
print(f"The missing values or null values count in User review data is {new_ur_data.isnull().sum().sum()}")
# Out:
# The missing values or null values count in Play store data is 1478
# The missing values or null values count in User review data is 3933

# %%
# Visualizing the missing values
new_ps_data.isna().sum()[new_ps_data.isna().sum()>0].plot(kind='bar')
# Out:
# <Axes: >

# %%
new_ur_data.isna().sum()[new_ur_data.isna().sum()>0].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
columns_ps = [col for col in new_ps_data.columns]
print("Columns of Playstore data:", columns_ps)
columns_ur = [col for col in new_ur_data.columns]
print("Columns of User review data:", columns_ur)
# Out:
# Columns of Playstore data: ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# Columns of User review data: ['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity', 'Sentiment_Subjectivity']

# %%
# Dataset Describe
new_ps_data.describe()
# Out:
#             Rating
# count  8893.000000
# mean      4.189542
# std       0.545452
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
new_ur_data.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        29697.000000            29697.000000
# mean             0.188836                0.490848
# std              0.355672                0.266029
# min             -1.000000                0.000000
# 25%              0.000000                0.350000
# 50%              0.157143                0.514286
# 75%              0.422500                0.652500
# max              1.000000                1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print("Unique values in Playstore Data are")
print("\n")
for column in new_ps_data.columns:
  unique_values = new_ps_data[column].unique()
  print(f"Unique values in '{column}':")
  print(unique_values)
  print("\n")
# Out:
# Unique values in Playstore Data are
#
#
# Unique values in 'App':
# ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
#
#
# Unique values in 'Category':
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']
#
#
# Unique values in 'Rating':
# [ 4.1  3.9  4.7  4.5  4.3  4.4  3.8  4.2  4.6  3.2  4.   nan  4.8  4.9
# ...

# %%
print("Unique values in User reviews Data are")
print("\n")
for column in new_ur_data.columns:
  unique_values = new_ur_data[column].unique()
  print(f"Unique values in '{column}':")
  print(unique_values)
  print("\n")
# Out:
# Unique values in User reviews Data are
#
#
# Unique values in 'App':
# ['10 Best Foods for You' '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室' '11st' ...
#  'Hotwire Hotel & Car Rental App' 'Housing-Real Estate & Property'
#  'Houzz Interior Design Ideas']
#
#
# Unique values in 'Translated_Review':
# ['I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"'
#  'This help eating healthy exercise regular basis' nan ...
#  'Dumb app, I wanted post property rent give option. Website work. Waste time space phone.'
#  'I property business got link SMS happy performance still guys need raise bar guys Cheers'
#  'Useless app, I searched flats kondapur, Hyderabad . None number reachable I know flats unavailable would keep posts active']
#
#
# Unique values in 'Sentiment':
# ['Positive' nan 'Neutral' 'Negative']
#
#
# Unique values in 'Sentiment_Polarity':
# [ 1.          0.25               nan ... -0.52857143 -0.37777778
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# Removing the null values in the both data sets

# %%
# Write your code to make your dataset analysis ready.
new_ps_data.dropna(inplace = True)
new_ps_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
new_ps_data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
new_ur_data.dropna(inplace = True)
new_ur_data
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
new_ur_data.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %% [markdown]
# ###Data Cleaning

# %%
def convert_float(a):
  a = str(a)
  for i in a:
    if i in ',+Mk$':
      if i == 'k':
        a = str(a).replace(i,'')
        a = eval(a)/1024.0
      a = str(a).replace(i,'')
  if a == 'Free' or a =='Varies with device'or a =='Everyone':
    a=0
  else:
    a=eval(str(a))
  return a

# %%
def convert_Million(a):
  if 'M' in a:
    a = str(a).replace('M', '')
    a = eval(str(a)) * 1000000
  return a

# %%
#convert installs,price,reviews to float value so that it better for calculation
new_ps_data['Installs'] = new_ps_data['Installs'].apply(convert_float)
new_ps_data['Price'] = new_ps_data['Price'].apply(convert_float)
new_ps_data['Size'] = new_ps_data['Size'].apply(convert_float)

# %%
new_ps_data['Reviews'] = new_ps_data['Reviews'].apply(convert_Million)

# %%
new_ps_data.head(100)
# Out:
#                                                    App           Category  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                  Coloring book moana     ART_AND_DESIGN
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                                Sketch - Draw & Paint     ART_AND_DESIGN
# 4                Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# ..                                                 ...                ...
# 97                                         Gas Station  AUTO_AND_VEHICLES
# 98                          Hush - Beauty for Everyone             BEAUTY
# 99                      ipsy: Makeup, Beauty, and Tips             BEAUTY
# 100                    Natural recipes for your beauty             BEAUTY
# 101  BestCam Selfie-selfie, beauty camera, photo ed...             BEAUTY
#
#      Rating Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
new_ps_data['Size'].dtype
# Out:
# dtype('float64')

# %%
new_ps_data1 = pd.DataFrame(new_ps_data)
new_ps_data1.sort_values(by='Reviews',ascending=False, inplace=True)

new_ps_data1 = new_ps_data1.drop_duplicates(subset=['App'])
new_ps_data1
# Out:
#                                     App          Category  Rating Reviews  \
# 2989             GollerCepte Live Score            SPORTS     4.2    9992
# 4970       Ad Block REMOVER - NEED ROOT             TOOLS     3.3     999
# 2705                SnipSnap Coupon App          SHOPPING     4.2    9975
# 3229                         DreamTrips  TRAVEL_AND_LOCAL     4.7    9971
# 3049  US Open Tennis Championships 2018            SPORTS     4.0    9971
# ...                                 ...               ...     ...     ...
# 7806                        CR Magazine          BUSINESS     1.0       1
# 5268            AJ Rafael Music Lessons            FAMILY     5.0       1
# 9247                          EC SPORTS            SPORTS     5.0       1
# 9251                            EC Reps          BUSINESS     4.0       1
# 8411                             DH-UFO            FAMILY     5.0       1
#
#            Size  Installs  Type  Price Content Rating          Genres  \
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
#code 1 Bar Plot for App Count for Different Categories
Categories = 'Category'
data = new_ps_data1[Categories]
category_counts = new_ps_data1[Categories].value_counts().reset_index()
category_counts.columns = ['Category', 'App Count']

# Sort the data by 'App Count' in descending order
category_counts = category_counts.sort_values(by='App Count', ascending=False)

plt.figure(figsize=(12, 9))
sns.barplot(x='App Count', y='Category', data=category_counts)
plt.xlabel('Number of Apps')
plt.ylabel(Categories)
plt.title('Bar Plot for App Count for Different Categories')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To pick the top categories on Google Playstore.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The dataset contains a total of 33 categories. From the provided output, it is evident that the majority of apps in the Play Store fall under the "Family" and "Game" categories, while the "Parenting" and "Beauty" categories have the fewest apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Categories: Focus on Popular Categories: If the business is involved in app development or distribution, knowing that "Family" and "Game" categories are the most popular can inform decisions to develop or promote apps in these categories. This can potentially lead to higher user engagement and revenue.
#
#
# Neglected Categories: Depending on the business's current portfolio, if it has invested heavily in categories that are less popular (e.g., "Parenting" or "Beauty"), it may see slower growth or lower returns on investment.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 Analysing the user Subjectivity
# Handle missing data if needed (e.g., drop rows with NaN values)
new_ur_data.dropna(subset=['Sentiment_Subjectivity'], inplace=True)

# Extract the 'Sentiment_Subjectivity' column
sentiment_subjectivity_df = new_ur_data['Sentiment_Subjectivity']

# Create a histogram (distribution plot) of subjectivity
sns.histplot(sentiment_subjectivity_df, kde=True)  # Using histplot for newer Seaborn versions
plt.xlabel("Subjectivity")
plt.title('Distribution of Subjectivity')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The majority of users tend to provide reviews for applications based on their experiences, with the highest concentration of sentiment subjectivity falling within the range of 0.4 to 0.7.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# You can identify the central tendency of user sentiment. In this case, it appears that the most common sentiment subjectivity values are between 0.4 and 0.7, indicating that users are typically providing reviews based on their experiences, which fall within this range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Understanding User Sentiment: Knowing that the majority of users provide reviews based on their experiences within a specific subjectivity range (0.4 to 0.7) can be valuable. It suggests that users are actively engaged and willing to provide feedback, which can be used to identify strengths and areas for improvement in the application.
#
#
# Negative Growth Considerations:
#
# Limited Negative Feedback: If the distribution shows a lack of highly negative sentiment (subjectivity < 0.4), it might mean that users are not providing critical feedback when needed. This could lead to complacency and a failure to address important issues, potentially resulting in negative growth in the long run.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3
# Calculate value counts
content_rating_counts = new_ps_data1['Content Rating'].value_counts()

# Extract x and y values
x2sis = content_rating_counts.index
y2sis = content_rating_counts

# Create the bar chart
plt.figure(figsize=(10, 8))
sns.barplot(x=x2sis, y=y2sis, alpha=0.9)
plt.title('Content Rating', size=20)
plt.ylabel('Apps(Count)')
plt.xlabel('Content Rating')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find which category of Apps from the Content Rating column are found more on playstore.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above plot we can see that Everyone category has the highest number of apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Target Audience: Knowing that the "Everyone" category has the highest number of apps indicates that a broad audience segment prefers these apps. This insight can be leveraged to develop and market apps that cater to a wide range of users, potentially increasing user adoption and revenue.
#
#
# Negative Growth:
#
# Increased Competition: The popularity of the "Everyone" category likely means increased competition. Businesses entering this category must be prepared to face competition from a large number of apps, which can make it challenging to stand out and achieve growth.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 distribution of the ratings of the apps
new_ps_data1['Rating'].describe()
# Out:
# count    8190.000000
# mean        4.173162
# std         0.536589
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(12, 8))
plt.xlabel("Rating")
plt.ylabel("Frequency")
sns.kdeplot(data=new_ps_data1['Rating'], color="red", shade=True)
plt.title('Distribution of App Ratings', size=20)
plt.show()
# Out:
# <ipython-input-35-190372a02395>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=new_ps_data1['Rating'], color="red", shade=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see the distribution of the ratings of the apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  From the above graph we can come to a conclusion that most of the apps in google playstore are rated in between 3.5 to 4.8

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# User Satisfaction: Understanding that many apps have ratings in the range of 3.5 to 4.8 can indicate that a substantial portion of users are generally satisfied with the available apps. This insight can reinforce the importance of maintaining high-quality apps that meet user expectations.
#
#
# Negative Growth:
#
# User Expectations: Relying solely on average ratings can be risky if it leads to complacency. If a business assumes that its apps are doing well simply because they fall within the common rating range, it might neglect the need for continuous improvement and innovation.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 percentage of paid apps vs free apps
no_of_apps = new_ps_data1['Type'].value_counts()
labels = no_of_apps.index
sizes = no_of_apps.values
custom_colors = ['orange', 'blue']
plt.figure(figsize=(12, 8))
plt.pie(sizes, labels=labels, autopct='%1.2f%%', startangle=140, colors = custom_colors, explode=(0, 0.1))
plt.title('Pie Chart of paid apps vs free apps')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the percentage of paid apps and free apps

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pie chart, we can say that the percentage of paid apps is very low compared to free apps. In the Play Store, we can find more number of free apps to download.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# User Attraction: The data suggests that most users prefer free apps, which can be a positive insight for businesses aiming to attract a large user base. Offering free apps can help in attracting a wider audience and increasing user engagement.
#
#
# Negative Business Impact:
#
# Revenue Generation: While offering free apps can attract a larger user base, it may negatively impact immediate revenue generation. If a business heavily relies on upfront app purchase fees, this insight could lead to a decrease in revenue.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 Which category of apps has the highest number of installations?
installs_high = new_ps_data1.groupby('Category')[['Installs']].sum().sort_values(by='Installs', ascending=False)
plt.figure(figsize=(12, 8))
sns.barplot(x=installs_high["Installs"], y=installs_high.index, alpha=0.9)
plt.xlabel("Installs")
plt.ylabel("Category")
plt.title("Installs", fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show which category of apps has the highest number of installations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The visualization suggests that the categories with the most significant number of installations include Game, Communication, Family, Tools, and Productivity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Targeted Marketing: Knowing which categories are popular among users allows businesses to focus their marketing efforts and resources on these categories. This can result in more efficient user acquisition and engagement strategies, potentially leading to increased revenue.
#
#
# Negative Business Impact:
#
# Increased Competition: The popularity of these categories also means increased competition. Entering highly competitive categories can be challenging for new businesses or apps with limited resources. It may require substantial marketing and development efforts to stand out.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7  top 10 expensive Apps in playstore

top_paid = new_ps_data1[new_ps_data1['Type'] == 'Paid'].sort_values(by='Price', ascending=False).head(11)
remove_value = "I am Rich!"
top_paid = top_paid[top_paid['App'] != remove_value]

# %%
plt.figure(figsize=(10,8));
plt.pie(top_paid.Installs, explode=None, labels=top_paid.App, autopct='%1.1f%%', startangle=0, labeldistance=1.1, textprops={'fontsize': 8});
plt.subplots_adjust(left=0.2, right=0.9, top=0.9, bottom=0.2)
plt.title('Top Expensive Apps Distribution',size = 16);
plt.legend(top_paid.App,
           loc="lower right",
           title="Apps",
           fontsize = "7"
          );

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the ten most costly apps available on the Play Store.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Based on the graph presented, it can be inferred that the "I am Rich" app is the most expensive application on the Google Play Store.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Premium Pricing Strategy: If a business specializes in luxury or high-end products and services, this insight can serve as a benchmark for premium pricing strategies. It may encourage the development of exclusive apps or content for a niche audience willing to pay a premium.
#
# Negative Business Impact:
#
# Limited Market: Setting extremely high prices can significantly limit the potential market size. Most users may be unwilling to spend such a large amount on an app, leading to a narrow customer base and reduced growth potential.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 Sentiment percentage analyse on user review dataset
sentiment_counts = new_ur_data['Sentiment'].value_counts()

sentiments = ['Positive', 'Neutral', 'Negative']  # Replace with your sentiment labels
# Explode values for each slice
explode = (0, 0.1, 0.1)
# Create a pie chart
plt.pie(sentiment_counts, labels=sentiments, explode=explode, shadow=True, autopct='%1.2f%%', pctdistance=1.2, labeldistance=1.4)
# Add a title
plt.title('Sentiment Distribution')
# Display the pie chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the sentiment percentage analyse

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart clearly indicates a predominance of positive reviews, suggesting an overall positive sentiment among users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Customer Satisfaction: The high number of positive reviews indicates that customers are generally satisfied with the product or service. This satisfaction can lead to customer loyalty, positive word-of-mouth recommendations, and repeat business, all of which can positively impact revenue and growth.
#
# Negative Growth Considerations:
#
# Complacency: A high number of positive reviews can sometimes lead to complacency. If a business assumes everything is perfect based solely on positive feedback and neglects areas of improvement, it could hinder growth in the long run. Continuous improvement is vital for staying competitive.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 Distribution of different apps according to their size

# %%
plt.figure(figsize=(12, 8))
size1 = new_ps_data1['Size']
plt.hist(size1, color = 'purple')
plt.xlabel("Size")
plt.title(" Distribution of different apps according to their size")
plt.ylabel("Number of apps")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the distribution of different apps according to their size

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# You can observe the range of app sizes within the dataset. The histogram shows how many apps fall into different size bins, providing an overview of the size distribution.
# You can identify the most common size ranges for apps. Peaks or high-frequency bins in the histogram indicate popular size categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Optimization Opportunities: Identifying size clusters or patterns in the distribution can lead to optimization opportunities. If there's a concentration of apps in a particular size range, developers can work on optimizing the size of their apps. Smaller app sizes can lead to faster downloads, reduced storage requirements, and improved user experience, which can positively impact user satisfaction and retention.
#
#
# Negative Growth Considerations:
#
# Limited Features: Over-optimizing for size may lead to the removal of essential features or quality compromises. If size reduction sacrifices functionality or user experience, it can result in negative user rev

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 apps rating based of size on differnt type(paid or free)

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=new_ps_data1, x = new_ps_data1['Size'], y = new_ps_data1['Rating'], hue = new_ps_data1['Type'])
plt.xlabel("Size")
plt.ylabel("Rating")
plt.title("Apps rating based of size on differnt type(paid or free)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Showing the rating of apps based on size on differnt type(paid or free)through visualisation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart clearly distinguishes between paid and free apps through color-coding. We compared how paid and free apps differ in terms of size and user ratings. In this free apps are getting more ranting than paid.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the scatter plot of app ratings based on size, categorized by type (paid or free), can potentially help create a positive business impact.
#
#
# Positive Business Impact:
#
# Optimization Opportunities: Identifying size-rating patterns can lead to optimization opportunities. If the data suggests that users generally prefer smaller apps with higher ratings, businesses can prioritize optimizing app size while maintaining or enhancing quality. This can lead to improved user satisfaction, better user retention, and potentially positive business impact.
#
#
# Negative Growth Considerations:
#
# Overemphasis on Size: Focusing solely on reducing app size without considering other factors, such as functionality and performance, can lead to negative growth. If optimization efforts compromise the quality or features of the app, user satisfaction may decline, resulting in negative reviews and reduced growth prospects.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 Apps percent for different age groups
content_rating = new_ps_data1['Content Rating']
content_rating
# Out:
# 2989    Everyone
# 4970    Everyone
# 2705    Everyone
# 3229        Teen
# 3049    Everyone
#           ...
# 7806    Everyone
# 5268    Everyone
# 9247    Everyone
# 9251    Everyone
# 8411    Everyone
# Name: Content Rating, Length: 8190, dtype: object

# %%
plt.figure(figsize=(12,8))
plt.title("Apps percent for different age groups")
plt.pie(content_rating.value_counts(), labels=content_rating.value_counts().index,explode=(0,0.1,0.1,0.1,1,2.3),autopct='%1.1f%%',startangle=180)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the ratings given by different age of people.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above pie chart we can say that "Everyone" is the largest slice, it indicates that a significant portion of apps is suitable for users of all ages.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the distribution of apps across different age groups based on their content ratings can potentially help create a positive business impact.
#
#
# Positive Business Impact:
#
# Targeted Marketing: Understanding the dominant age group for your app or the availability of niche categories can help businesses tailor their marketing strategies. They can create targeted campaigns to reach specific age demographics, potentially leading to increased downloads and user engagement.
#
#
# Negative Growth Considerations:
#
# Exclusivity: Overemphasizing apps for a specific age group, while neglecting others, can lead to exclusivity. If businesses cater solely to one demographic and ignore the broader market, it may limit their growth potential and alienate potential users from other age groups.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 The last updates that is done to apps

# %%
def extract_year(str):
  from datetime import datetime
  # Input date string
  date_string = str
  # Convert the date string to a datetime object
  date_object = datetime.strptime(date_string, '%B %d, %Y')
  # Extract the year
  year = date_object.year
  return year

# %%
updates = new_ps_data1['Last Updated'].apply(extract_year)
updates.dropna()
updates.value_counts()
# Out:
# 2018    5447
# 2017    1424
# 2016     628
# 2015     379
# 2014     184
# 2013      91
# 2012      21
# 2011      15
# 2010       1
# Name: Last Updated, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.barplot(x = updates.value_counts().index, y = updates.value_counts(), alpha=0.9)
plt.xlabel("Last updated")
plt.title("The last updates that is done to apps")
plt.ylabel("Number of apps")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Showing the last updates that is done to apps

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart illustrates the frequency of app updates over different years. In 2018 year had a higher number of app updates and 2010 year had no updates and 2011 had fewer updates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the distribution of app updates over time can potentially help create a positive business impact if leveraged effectively.
#
#
# Positive Business Impact:
#
# User Satisfaction: Regular updates, especially in recent years, indicate a commitment to improving app quality and addressing user feedback. This can lead to higher user satisfaction, positive reviews, and increased user retention, all of which contribute to positive business growth.
#
#
# Negative Growth Considerations:
#
# Over-Reliance on Updates: Overemphasizing frequent updates at the expense of app stability and quality can lead to negative growth. Users may become frustrated with constant changes or issues introduced with each update, resulting in negative reviews and decreased user retention.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 Number of apps that is supported in different andriod versions
Versions = new_ps_data1['Android Ver']
Versions = pd.DataFrame(Versions)
Versions = Versions[Versions['Android Ver'] != 'Varies with device']
Versions.dropna()
# Out:
#        Android Ver
# 2989    4.1 and up
# 4970    2.2 and up
# 2705    4.3 and up
# 3229    5.0 and up
# 3049    5.0 and up
# ...            ...
# 7806  2.3.3 and up
# 5268    4.1 and up
# 9247  2.3.3 and up
# 9251    4.0 and up
# 8411    4.4 and up
#
# [7243 rows x 1 columns]

# %%
plt.figure(figsize = (12,8))
sns.barplot(x = Versions['Android Ver'].value_counts().index, y = Versions['Android Ver'].value_counts(), alpha=0.9)
plt.xticks(rotation= 90)
plt.xlabel("Andriod versions")
plt.title("Number of apps that is supported in different andriod versions")
plt.ylabel("Number of apps")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Showing the number of apps that is supported in different andriod versions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart illustrates the popularity of different Android versions among app developers. 4.1 and up android versions have the highest number of supported apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight that "4.1 and up" Android versions have the highest number of supported apps can have both positive and potentially negative implications for businesses.
#
#
# Positive Business Impact:
#
# Broad User Base: Supporting "4.1 and up" Android versions means that businesses can reach a broad user base, as these versions cover a significant portion of the Android market. This broad reach can lead to increased app downloads and potential revenue growth.
#
#
# Negative Growth Considerations:
#
# Exclusion of Older Devices: While targeting "4.1 and up" versions is beneficial for reaching a broad audience, it may exclude users with older devices running unsupported versions. This exclusion can limit market reach and potential growth among users with legacy devices.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
new_ps_data2 =new_ps_data1[["Rating","Reviews","Installs","Size","Price"]]
new_ps_data2
# Out:
#       Rating Reviews  Installs       Size  Price
# 2989     4.2    9992   1000000  31.000000    0.0
# 4970     3.3     999    100000   0.088867    0.0
# 2705     4.2    9975   1000000  18.000000    0.0
# 3229     4.7    9971    500000  22.000000    0.0
# 3049     4.0    9971   1000000  33.000000    0.0
# ...      ...     ...       ...        ...    ...
# 7806     1.0       1       100   7.800000    0.0
# 5268     5.0       1        10   8.200000    0.0
# 9247     5.0       1        10   6.300000    0.0
# 9251     4.0       1       100   5.400000    0.0
# 8411     5.0       1       100  59.000000    0.0
#
# [8190 rows x 5 columns]

# %%
new_ps_data2.dropna()
# Out:
#       Rating  Reviews   Installs       Size  Price
# 2989     4.2   9992.0  1000000.0  31.000000    0.0
# 4970     3.3    999.0   100000.0   0.088867    0.0
# 2705     4.2   9975.0  1000000.0  18.000000    0.0
# 3229     4.7   9971.0   500000.0  22.000000    0.0
# 3049     4.0   9971.0  1000000.0  33.000000    0.0
# ...      ...      ...        ...        ...    ...
# 7806     1.0      1.0      100.0   7.800000    0.0
# 5268     5.0      1.0       10.0   8.200000    0.0
# 9247     5.0      1.0       10.0   6.300000    0.0
# 9251     4.0      1.0      100.0   5.400000    0.0
# 8411     5.0      1.0      100.0  59.000000    0.0
#
# [8190 rows x 5 columns]

# %%
new_ps_data2.loc[:, 'Reviews'] = new_ps_data2['Reviews'].astype(float)
# Out:
# <ipython-input-172-6fdb937cd0e5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ps_data2.loc[:, 'Reviews'] = new_ps_data2['Reviews'].astype(float)

# %%
column_data_types = new_ps_data2.dtypes
# Print the data types
print(column_data_types)
# Out:
# Rating      float64
# Reviews     float64
# Installs    float64
# Size        float64
# Price       float64
# dtype: object

# %%
variables = new_ps_data2.groupby('Rating').sum().reset_index()
variables
# Out:
#     Rating      Reviews      Installs          Size    Price
# 0      1.0         28.0  5.170000e+03    228.800000     4.48
# 1      1.2         44.0  1.000000e+03     27.000000     0.00
# 2      1.4         98.0  7.000000e+03     20.200000     0.00
# 3      1.5         61.0  1.105000e+03     54.000000     0.00
# 4      1.6        691.0  1.520000e+05     64.600000     0.00
# 5      1.7       2360.0  8.170000e+04     80.300000     4.99
# 6      1.8       3418.0  5.195000e+05     49.066211     1.49
# 7      1.9       1875.0  1.890000e+05    154.200000     0.00
# 8      2.0       2997.0  5.040150e+06    191.400000     4.59
# 9      2.1       3073.0  1.820000e+05    164.200000     0.00
# 10     2.2       1979.0  2.130600e+06    217.400000     0.00
# 11     2.3       2361.0  2.641000e+05    344.600000     2.48
# 12     2.4      14829.0  1.284100e+06    275.780664     5.98
# 13     2.5      14807.0  2.078100e+06    359.851172     3.99
# ...

# %%
fig, axes = plt.subplots(figsize=(8, 8))
plt.title("Co-relations of variables using a heatmap", fontsize=16)
sns.heatmap(variables.corr(), ax=axes, annot=True, linewidths=0.1, fmt='.2f', square=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# generate a correlation heatmap that visualizes the relationships between the 'Rating' column and other numeric variables in dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 'Rating' has a strong positive correlation with 'Number of Reviews,' it implies that highly-rated apps tend to have more reviews.
#
# 'Rating' has a strong negative correlation with 'Price,' it implies that highly-rated apps are typically lower in price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the correlation heatmap can potentially help create a positive business impact, but they must be interpreted and acted upon judiciously.
#
# Positive Business Impact:
#
# Feature Selection: Identifying variables strongly correlated with 'Rating' can guide feature selection for app development. Focusing on features that positively impact ratings can lead to improved user satisfaction, positive reviews, and potentially increased downloads and revenue.
#
# Negative Growth Considerations:
#
# Causation Fallacy: Correlation does not imply causation. Relying solely on correlations to make business decisions can be misleading. Businesses should be cautious about assuming that changing a variable will directly impact 'Rating' without conducting further experiments or studies.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
variables1 = ['Reviews', 'Size', 'Installs', 'Price']

# %%
fig, axes = plt.subplots(1, 4, figsize=(15, 4))

colors = ['r', 'c', 'm', 'y']

for i, variable in enumerate(variables1):
    axes[i].plot(variables['Rating'], variables[variable], colors[i])
    axes[i].set_xlabel('Rating')
    axes[i].set_ylabel(variable)
    axes[i].set_title(f'{variable} Per Rating', fontsize=16)
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Created a set of four subplots in a row, each displaying a line plot of a different variable ('Reviews', 'Size', 'Installs', 'Price') against the 'Rating'.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This plot might show whether there is any correlation or pattern between the number of reviews an app has and its rating. You could look for trends such as highly-rated apps having more reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Whether the insights gained from the pair plots will help create a positive business impact or potentially lead to negative growth depends on the specific findings in the data and how those findings are leveraged.
#
# Positive Impact: If the plot shows a strong positive correlation between the number of reviews and rating, it suggests that as an app receives more reviews, it tends to have higher ratings. This insight could be used to focus on strategies to encourage more user reviews, as higher ratings can attract more users and increase the app's popularity.
#
#
# Negative Impact: However, solely focusing on generating more reviews without improving the quality of the app can lead to negative growth. If users leave negative reviews due to poor app quality, it can harm the app's reputation and lead to a decline in user base.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objectives for a Play Store Review Analysis project, I would suggest the following key goals and strategies:
#
# 1. Improve App Ratings and User Satisfaction:
#
# The primary objective should be to enhance app ratings and overall user satisfaction. Higher ratings generally lead to more downloads and increased user loyalty.
# Strategy: Analyze user reviews to identify common complaints and issues users face with the app. Use this feedback to prioritize and address these issues in app updates. Continuous improvement of the app's user experience should be a top priority.
#
# 2. Increase App Downloads and User Base:
#
# Expanding the user base is often a critical business objective. Attracting new users while retaining existing ones is essential for growth.
# Strategy: Implement marketing and advertising campaigns based on insights gained from user reviews. Highlight positive aspects of the app and address any concerns raised by users. Monitor the impact of these campaigns on downloads and user acquisition.
# 3. Enhance App Features and Functionality:
#
# Regularly updating the app with new features and improvements can lead to increased user engagement and satisfaction.
# Strategy: Analyze user feedback to identify feature requests and areas where the app can be enhanced. Prioritize these enhancements in development cycles to provide users with the features they desire.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the Play Store Review Analysis project is a valuable endeavor for improving an app's overall performance and achieving key business objectives. By carefully analyzing user reviews and feedback, the project aims to drive positive outcomes, including:
#
#
# Overall, the success of this project hinges on a commitment to continuous improvement, a strong focus on user-centricity, and the utilization of insights gained from user reviews to drive positive changes in the app. By aligning these efforts with the broader business objectives, the project can contribute significantly to the app's growth and success in the highly competitive app market.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
